# %% [markdown]
# # **Scraping Data Twitter**

# %% [markdown]
# **Install Dependencies**

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:2 https://cli.github.com/packages stable InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,080 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,368 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,429 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:15 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,755 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,742 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,278 kB]
# Get:19 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,816 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,584 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,936 kB]
# Fetched 36.4 MB in 5s (7,571 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.21).
# gnupg is already the newest version (2.2.27-3ubuntu2.4).
# gnupg set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_20.x nodistro main
# Get:1 https://deb.nodesource.com/node_20.x nodistro InRelease [12.1 kB]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 https://deb.nodesource.com/node_20.x nodistro/main amd64 Packages [12.9 kB]
# Hit:4 https://cli.github.com/packages stable InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 25.1 kB in 2s (13.6 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 32.0 MB of archives.
# After this operation, 197 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_20.x nodistro/main amd64 nodejs amd64 20.19.5-1nodesource1 [32.0 MB]
# Fetched 32.0 MB in 0s (63.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../nodejs_20.19.5-1nodesource1_amd64.deb ...
# Unpacking nodejs (20.19.5-1nodesource1) ...
# Setting up nodejs (20.19.5-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...
# v20.19.5

# %%
#@title Twitter Auth Token

twitter_auth_token = 'ea6ba41b1684b67ac67467c792c75fcf527c9c8c'

# %% [markdown]
# **Definisikan keyword dan nama file**

# %%
# Crawl Data
filename = 'mbg.csv'
search_keyword = 'mbg lang:id'
limit = 1250

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠼npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠴npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: mbg lang:id
#
#  (2)Created new directory: /content/tweets-data
#
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 39
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 57
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 76
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 96
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 115
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 135
#
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 155
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 175
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 195
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 215
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 235
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 255
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 275
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 293
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 313
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 333
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 353
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 372
#
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 388
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 408
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 428
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 444
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 464
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 484
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 504
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 524
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 544
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 564
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 584
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 604
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 624
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 644
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 664
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 684
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 704
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 722
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 742
#
# -- Scrolling... (1)[v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@07419a399c90c6b26eaddbbde82a3e3b"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@dd97e3a822d4a43de0c214591d25bd11"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@ca7aa9f7ba53d042fc177f672a719957"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@cf19e31e9d594233224512cfee0b4994"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@4eb26c35fc86cacb3daa516f0e0f2688"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@28079a5f9c073711025b43fca4bad623"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@92884ca7ac143e72e1d4bb870cadf29a"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@697d11be7d8ae216030918dc6b246dfd"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@12681499d8f951786098bd41cd5be0f3"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@959457829b985c8515044411fc973827"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@9731835dd3483f2ba67517df24748ac7"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
#
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 762
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 782
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 802
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 822
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 842
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 856
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 876
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 896
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 914
#
# -- Scrolling... (1) (2) (3) (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 934
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3) (4) (5) (6) (7) (8)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 952
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 972
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 992
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1012
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1032
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1052
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1070
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1090
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1110
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1130
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1149
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1167
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1187
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1207
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1225
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1245
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/mbg.csv
# Total tweets saved: 1263
# Got 1263 tweets, done scrolling...
# ⠙

# %% [markdown]
# **Simpan Data**

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1978339661152993286  Wed Oct 15 16:40:00 +0000 2025               0
# 1     1978385366127128933  Wed Oct 15 16:39:25 +0000 2025               0
# 2     1978460854619341068  Wed Oct 15 16:39:16 +0000 2025               0
# 3     1977968505145422140  Wed Oct 15 16:39:14 +0000 2025               0
# 4     1978278879140647405  Wed Oct 15 16:38:52 +0000 2025               0
# ...                   ...                             ...             ...
# 1258  1978333588019204121  Wed Oct 15 05:34:17 +0000 2025               0
# 1259  1978333547329974278  Wed Oct 15 05:34:09 +0000 2025               0
# 1260  1978333493219274846  Wed Oct 15 05:33:55 +0000 2025               0
# 1261  1978333487494058027  Wed Oct 15 05:33:53 +0000 2025               0
# 1262  1978282081026212330  Wed Oct 15 05:33:35 +0000 2025               1
#
#                                               full_text               id_str  \
# 0     @JukiHoki Jadi MBG min... https://t.co/AbXHsQvMd6  1978501119853699275
# 1     @ryeonseunggg @52XYZ @ARSIPAJA konteks MBG unt...  1978500973673783639
# 2     @tempodotco Lah kenapa? Nasi 10rb dsni udh ena...  1978500937141420216
# 3     @blossomjarr gakan keracunan kan bukan menu mb...  1978500928366903326
# 4     @ifti_tahida MBG naik level dimulai dengan tin...  1978500833495949394
# ...                                                 ...                  ...
# 1258  Dinkes Kota Malang Temukan Mikroba pada Menu M...  1978333588019204121
# 1259   Yuk kenali lebih jauh soal tujuan dan proses ...  1978333552342159703
# 1260  Hal itu ditegaskan Dadan saat memberikan araha...  1978333493219274846
# 1261  program mbg dan koperasi merah putih bukti per...  1978333487494058027
# 1262  @Ixan09 @Franken_blues kita benahi dulu. Kalau...  1978333409236627530
#
#                                             image_url in_reply_to_screen_name  \
# 0     https://pbs.twimg.com/media/G3UMSCYbAAEppbT.jpg                JukiHoki
# 1                                                 NaN            ryeonseunggg
# 2                                                 NaN              tempodotco
# 3                                                 NaN             blossomjarr
# 4                                                 NaN             ifti_tahida
# ...                                               ...                     ...
# 1258                                              NaN                     NaN
# 1259  https://pbs.twimg.com/media/G3RzxFwbkAAYA9v.jpg             humasjateng
# 1260                                              NaN                     NaN
# 1261  https://pbs.twimg.com/media/G3RzwlRa0AA0xIc.jpg                     NaN
# 1262                                              NaN                  Ixan09
#
#      lang  location  quote_count  reply_count  retweet_count  \
# 0      in       NaN            0            0              0
# 1      in       NaN            0            0              0
# 2      in       NaN            0            0              0
# 3      in       NaN            0            0              0
# 4      in       NaN            0            0              0
# ...   ...       ...          ...          ...            ...
# 1258   in       NaN            0            1              0
# 1259   in       NaN            0            0              0
# 1260   in       NaN            0            0              0
# 1261   in       NaN            0            0              0
# 1262   in       NaN            0            0              0
#
#                                               tweet_url          user_id_str  \
# 0     https://x.com/undefined/status/197850111985369...            144032883
# 1     https://x.com/undefined/status/197850097367378...  1333450664500887553
# 2     https://x.com/undefined/status/197850093714142...  1480062809245249539
# 3     https://x.com/undefined/status/197850092836690...  1544216292017577985
# 4     https://x.com/undefined/status/197850083349594...  1688491503268896769
# ...                                                 ...                  ...
# 1258  https://x.com/undefined/status/197833358801920...  1318893514336264193
# 1259  https://x.com/undefined/status/197833355234215...           2276246437
# 1260  https://x.com/undefined/status/197833349321927...             68930552
# 1261  https://x.com/undefined/status/197833348749405...  1725525024311054336
# 1262  https://x.com/undefined/status/197833340923662...  1896888621384466433
#
#       username
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 1258       NaN
# 1259       NaN
# 1260       NaN
# 1261       NaN
# 1262       NaN
#
# [1263 rows x 15 columns]

# %% [markdown]
# **Cek Dataframe**

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")

df = df.drop_duplicates()

df.to_excel("mbg.xlsx", index=False)
# Out:
# Jumlah tweet dalam dataframe adalah 1263.

# %% [markdown]
# ## **Casefolding**

# %%
df['casefolding'] = df['full_text'].str.lower()
df_casefolding = df[['full_text','casefolding']]

# %%
df
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1978339661152993286  Wed Oct 15 16:40:00 +0000 2025               0
# 1     1978385366127128933  Wed Oct 15 16:39:25 +0000 2025               0
# 2     1978460854619341068  Wed Oct 15 16:39:16 +0000 2025               0
# 3     1977968505145422140  Wed Oct 15 16:39:14 +0000 2025               0
# 4     1978278879140647405  Wed Oct 15 16:38:52 +0000 2025               0
# ...                   ...                             ...             ...
# 1258  1978333588019204121  Wed Oct 15 05:34:17 +0000 2025               0
# 1259  1978333547329974278  Wed Oct 15 05:34:09 +0000 2025               0
# 1260  1978333493219274846  Wed Oct 15 05:33:55 +0000 2025               0
# 1261  1978333487494058027  Wed Oct 15 05:33:53 +0000 2025               0
# 1262  1978282081026212330  Wed Oct 15 05:33:35 +0000 2025               1
#
#                                               full_text               id_str  \
# 0     @JukiHoki Jadi MBG min... https://t.co/AbXHsQvMd6  1978501119853699275
# 1     @ryeonseunggg @52XYZ @ARSIPAJA konteks MBG unt...  1978500973673783639
# 2     @tempodotco Lah kenapa? Nasi 10rb dsni udh ena...  1978500937141420216
# 3     @blossomjarr gakan keracunan kan bukan menu mb...  1978500928366903326
# 4     @ifti_tahida MBG naik level dimulai dengan tin...  1978500833495949394
# ...                                                 ...                  ...
# 1258  Dinkes Kota Malang Temukan Mikroba pada Menu M...  1978333588019204121
# 1259   Yuk kenali lebih jauh soal tujuan dan proses ...  1978333552342159703
# 1260  Hal itu ditegaskan Dadan saat memberikan araha...  1978333493219274846
# 1261  program mbg dan koperasi merah putih bukti per...  1978333487494058027
# 1262  @Ixan09 @Franken_blues kita benahi dulu. Kalau...  1978333409236627530
#
#                                             image_url in_reply_to_screen_name  \
# 0     https://pbs.twimg.com/media/G3UMSCYbAAEppbT.jpg                JukiHoki
# 1                                                 NaN            ryeonseunggg
# 2                                                 NaN              tempodotco
# 3                                                 NaN             blossomjarr
# 4                                                 NaN             ifti_tahida
# ...                                               ...                     ...
# 1258                                              NaN                     NaN
# 1259  https://pbs.twimg.com/media/G3RzxFwbkAAYA9v.jpg             humasjateng
# 1260                                              NaN                     NaN
# 1261  https://pbs.twimg.com/media/G3RzwlRa0AA0xIc.jpg                     NaN
# 1262                                              NaN                  Ixan09
#
#      lang  location  quote_count  reply_count  retweet_count  \
# 0      in       NaN            0            0              0
# 1      in       NaN            0            0              0
# 2      in       NaN            0            0              0
# 3      in       NaN            0            0              0
# 4      in       NaN            0            0              0
# ...   ...       ...          ...          ...            ...
# 1258   in       NaN            0            1              0
# 1259   in       NaN            0            0              0
# 1260   in       NaN            0            0              0
# 1261   in       NaN            0            0              0
# 1262   in       NaN            0            0              0
#
#                                               tweet_url          user_id_str  \
# 0     https://x.com/undefined/status/197850111985369...            144032883
# 1     https://x.com/undefined/status/197850097367378...  1333450664500887553
# 2     https://x.com/undefined/status/197850093714142...  1480062809245249539
# 3     https://x.com/undefined/status/197850092836690...  1544216292017577985
# 4     https://x.com/undefined/status/197850083349594...  1688491503268896769
# ...                                                 ...                  ...
# 1258  https://x.com/undefined/status/197833358801920...  1318893514336264193
# 1259  https://x.com/undefined/status/197833355234215...           2276246437
# 1260  https://x.com/undefined/status/197833349321927...             68930552
# 1261  https://x.com/undefined/status/197833348749405...  1725525024311054336
# 1262  https://x.com/undefined/status/197833340923662...  1896888621384466433
#
#       username                                        casefolding
# 0          NaN  @jukihoki jadi mbg min... https://t.co/abxhsqvmd6
# 1          NaN  @ryeonseunggg @52xyz @arsipaja konteks mbg unt...
# 2          NaN  @tempodotco lah kenapa? nasi 10rb dsni udh ena...
# 3          NaN  @blossomjarr gakan keracunan kan bukan menu mb...
# 4          NaN  @ifti_tahida mbg naik level dimulai dengan tin...
# ...        ...                                                ...
# 1258       NaN  dinkes kota malang temukan mikroba pada menu m...
# 1259       NaN   yuk kenali lebih jauh soal tujuan dan proses ...
# 1260       NaN  hal itu ditegaskan dadan saat memberikan araha...
# 1261       NaN  program mbg dan koperasi merah putih bukti per...
# 1262       NaN  @ixan09 @franken_blues kita benahi dulu. kalau...
#
# [1263 rows x 16 columns]

# %%
df_casefolding
# Out:
#                                               full_text  \
# 0     @JukiHoki Jadi MBG min... https://t.co/AbXHsQvMd6
# 1     @ryeonseunggg @52XYZ @ARSIPAJA konteks MBG unt...
# 2     @tempodotco Lah kenapa? Nasi 10rb dsni udh ena...
# 3     @blossomjarr gakan keracunan kan bukan menu mb...
# 4     @ifti_tahida MBG naik level dimulai dengan tin...
# ...                                                 ...
# 1258  Dinkes Kota Malang Temukan Mikroba pada Menu M...
# 1259   Yuk kenali lebih jauh soal tujuan dan proses ...
# 1260  Hal itu ditegaskan Dadan saat memberikan araha...
# 1261  program mbg dan koperasi merah putih bukti per...
# 1262  @Ixan09 @Franken_blues kita benahi dulu. Kalau...
#
#                                             casefolding
# 0     @jukihoki jadi mbg min... https://t.co/abxhsqvmd6
# 1     @ryeonseunggg @52xyz @arsipaja konteks mbg unt...
# 2     @tempodotco lah kenapa? nasi 10rb dsni udh ena...
# 3     @blossomjarr gakan keracunan kan bukan menu mb...
# 4     @ifti_tahida mbg naik level dimulai dengan tin...
# ...                                                 ...
# 1258  dinkes kota malang temukan mikroba pada menu m...
# 1259   yuk kenali lebih jauh soal tujuan dan proses ...
# 1260  hal itu ditegaskan dadan saat memberikan araha...
# 1261  program mbg dan koperasi merah putih bukti per...
# 1262  @ixan09 @franken_blues kita benahi dulu. kalau...
#
# [1263 rows x 2 columns]

# %% [markdown]
# **Simpan CSV Full Kolom dan Hasil Casefolding**

# %%
df.to_csv("Hasil_Scraping_X.csv", index=False)
df_casefolding.to_csv("Hasil_Casefolding.csv", index=False)

# %%
# --- Step: Preprocessing Data ---

import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab') # Added download for punkt_tab

df = pd.read_csv('Hasil_Casefolding.csv')

text_column = 'casefolding'

def clean_text(text):
    if pd.isnull(text):
        return ""
    text = re.sub(r'http\S+|www\S+', '', text)
    text = re.sub(r'[@#]\w+', '', text)
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = text.encode('ascii', 'ignore').decode('ascii')
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df['clean_text'] = df[text_column].apply(clean_text)

df['tokenized'] = df['clean_text'].apply(lambda x: word_tokenize(x))

# 5. Stopword removal
stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(tokens):
    filtered = [word for word in tokens if word not in stop_words]
    return filtered

df['no_stopwords'] = df['tokenized'].apply(remove_stopwords)

# 6. (Opsional) Stemming
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemming(tokens):
    return [stemmer.stem(word) for word in tokens]

df['stemmed'] = df['no_stopwords'].apply(stemming)

# 7. Gabungkan kembali ke bentuk kalimat
df['final_text'] = df['stemmed'].apply(lambda x: ' '.join(x))

# 8. Simpan hasil preprocessing
output_path = 'Hasil_Preprocessing.csv'
df.to_csv(output_path, index=False, encoding='utf-8-sig')

print(f"✅ Preprocessing selesai! File disimpan ke: {output_path}")
df[['full_text', 'final_text']].head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ✅ Preprocessing selesai! File disimpan ke: Hasil_Preprocessing.csv
#                                            full_text  \
# 0  @JukiHoki Jadi MBG min... https://t.co/AbXHsQvMd6
# 1  @ryeonseunggg @52XYZ @ARSIPAJA konteks MBG unt...
# 2  @tempodotco Lah kenapa? Nasi 10rb dsni udh ena...
# 3  @blossomjarr gakan keracunan kan bukan menu mb...
# 4  @ifti_tahida MBG naik level dimulai dengan tin...
#
#                                           final_text
# 0                                            mbg min
# 1  konteks mbg baik gizi gizi segitu bahan baku p...
# 2  nasi rb dsni udh enak dpt ayam telor sayur sam...
# 3                               gakan racun menu mbg
# 4              mbg level tingkat mutu bareng prabowo

# %%
# !pip install Sastrawi
